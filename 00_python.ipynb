# %% [markdown]
# # 00.python?
#
#  - .py 파일을 만들기 위해서는 Python 문서 편집기로 편집을 해야한다.
#  - .py 파일을 실행하기 위해서는 Python 실행기로 실행한다. (Google Colaboratory)
#  - <font color='pink'>Anaconda</font> 는 파이썬 백과사전으로 불리며, 데이터 처리, 예측분석 등 머신러닝에 적합한 오픈 소스이다.
#
#
#  ## Anaconda 패키지 관리
#
#  - 자주 사용하는 `conda` 명령어
#
# <table>
# <thead><th>기능</th><th>명령어</th></thead><tbody>
# <tr><td>패키지설치</td><td><span style = 'background:blue'>$ conda install numpy</span></td></tr>
#
# <tr><td>동시에 여러 패키지 설치</td><td><span style = 'background:blue'>$ conda install numpy scipy pnadas</span></td></tr>
#
# <tr><td>특정버전 설치</td><td><span style = 'background:blue'>$ conda install numpy = 1.10</span></td></tr>
#
# <tr><td>패키지 제거</td><td><span style = 'background:blue'>$ conda remove 'package name'</span></td></tr>
#
# <tr><td>패키지 업데이트</td><td><span style = 'background:blue'>$ conda update 'package name'</span></td></tr>
#
# <tr><td>모든 패키지 업데이트</td><td><span style = 'background:blue'>$ conda update -all</span></td></tr>
#
# <tr><td>목록 출력</td><td><span style = 'background:blue'>$ conda list</span></td></tr>
#
# <tr><td>패키지 검색</td><td><span style = 'background:blue'>$ conda search 'search_term'</span></td></tr></tbody>
# </table>
#
# - Jupyter notebook \
# `$ conda install jupyter notebook`을 통한 설치 \
# config.py 문서파일에서 directory 설정
# ```python
# c.NotebookApp.notebook_dir = 'C:\python_basic'
# ```
